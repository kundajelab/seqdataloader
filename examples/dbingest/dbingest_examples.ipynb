# %%
#load  tutorial utilities 
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Ingesting data into tileDB

# %%
from seqdataloader.dbingest import *

# %% [markdown]
# The header of the input task file should contain (one or more) of the following fields:
#     * dataset (this one's required -- it's a unique label for your dataset)
#     * pval_bigwig
#     * fc_bigwig
#     * count_bigwig_plus_5p
#     * count_bigwig_minux_5p
#     * idr_peak
#     * overlap_peak
#     * ambig_peak
#
# The file paths can be either local or web-based URL's.

# %%
# !cat tasks.dbingest.tsv
# Out:
# dataset	idr_peak	fc_bigwig	ambig_peak
# ENCFF209DJG	https://www.encodeproject.org/files/ENCFF209DJG/@@download/ENCFF209DJG.bed.gz	https://www.encodeproject.org/files/ENCFF842XRQ/@@download/ENCFF842XRQ.bigWig	hg38.blacklist.bed.gz

# %%
# !cat tasks.dbingest.local.tsv
# Out:
# dataset	idr_peak	fc_bigwig	ambig_peak
# ENCFF209DJG	ENCFF209DJG.bed.gz	ENCFF842XRQ.bigWig	hg38.blacklist.bed.gz

# %% [markdown]
# ### run as script

# %%
## multi-threaded version is faster, but more qc is needed to determine an edge case where a lot of memory gets consumed 
# !db_ingest --tiledb_metadata tasks.dbingest.local.tsv \
    --tiledb_group hepg2_dnase_encode \
    --overwrite \
    --chrom_sizes hg38.chr10.size \
    --chrom_threads 1 \
    --task_threads 1 \
    --write_threads 30 \
    --attribute_config encode_pipeline \
    --tile_size 9000 \
    --batch_size 1000000
# Out:
# loaded tiledb metadata
# loaded chrom sizes
# tiledb group already exists
# parsed pool inputs
# made pool!
# warning: the array: hepg2_dnase_encode/ENCFF209DJG.chr10 already exists. You provided the --overwrite flag, so it will be updated/overwritten
# store_summits:True
# summit_indicator:2
# got:idr_peak for chrom:chr10
# store_summits:False
# summit_indicator:None
# 13.610400199890137
# got:fc_bigwig for chrom:chr10
# store_summits:False
# summit_indicator:None
# got:ambig_peak for chrom:chr10
# starting to write output
# got cur vals
# dict_to_write[key].shape:(133797422,)
# dict_to_write[key].shape:(133797422,)
# dict_to_write[key].shape:(133797422,)
# updated data dict for writing
# finalizing the write
# length of pool inputs:134
# made pool
# start:0, end:1000000
# start:1000000, end:2000000
# start:2000000, end:3000000
# start:3000000, end:4000000
# start:4000000, end:5000000
# start:5000000, end:6000000
# start:6000000, end:7000000
# start:7000000, end:8000000
# start:8000000, end:9000000
# start:9000000, end:10000000
# start:10000000, end:11000000
# start:11000000, end:12000000
# start:12000000, end:13000000
# start:13000000, end:14000000
# start:14000000, end:15000000
# start:15000000, end:16000000
# start:16000000, end:17000000
# start:17000000, end:18000000
# start:18000000, end:19000000
# start:19000000, end:20000000
# start:20000000, end:21000000
# start:21000000, end:22000000
# start:22000000, end:23000000
# start:23000000, end:24000000
# start:24000000, end:25000000
# start:25000000, end:26000000
# start:26000000, end:27000000
# done with chunk start:0, end:1000000
# done
# start:27000000, end:28000000
# start:28000000, end:29000000
# start:29000000, end:30000000
# start:30000000, end:31000000
# done with chunk start:1000000, end:2000000
# done
# start:31000000, end:32000000
# done with chunk start:2000000, end:3000000
# done
# start:32000000, end:33000000
# done with chunk start:3000000, end:4000000
# done
# start:33000000, end:34000000
# done with chunk start:4000000, end:5000000
# done
# start:34000000, end:35000000
# done with chunk start:5000000, end:6000000
# done
# start:35000000, end:36000000
# done with chunk start:6000000, end:7000000
# done
# start:36000000, end:37000000
# done with chunk start:7000000, end:8000000
# done
# start:37000000, end:38000000
# done with chunk start:8000000, end:9000000
# done
# start:38000000, end:39000000
# done with chunk start:10000000, end:11000000
# start:39000000, end:40000000
# done with chunk start:12000000, end:13000000
# start:40000000, end:41000000
# done with chunk start:14000000, end:15000000
# start:41000000, end:42000000
# done with chunk start:18000000, end:19000000
# start:42000000, end:43000000
# done with chunk start:21000000, end:22000000
# start:43000000, end:44000000
# done with chunk start:15000000, end:16000000
# start:44000000, end:45000000
# done with chunk start:29000000, end:30000000
# start:45000000, end:46000000
# done with chunk start:22000000, end:23000000
# start:46000000, end:47000000
# done with chunk start:31000000, end:32000000
# start:47000000, end:48000000
# done with chunk start:26000000, end:27000000
# start:48000000, end:49000000
# done with chunk start:30000000, end:31000000
# start:49000000, end:50000000
# done with chunk start:33000000, end:34000000
# start:50000000, end:51000000
# done with chunk start:16000000, end:17000000
# start:51000000, end:52000000
# done with chunk start:32000000, end:33000000
# start:52000000, end:53000000
# done with chunk start:35000000, end:36000000
# start:53000000, end:54000000
# done with chunk start:27000000, end:28000000
# start:54000000, end:55000000
# done with chunk start:28000000, end:29000000
# start:55000000, end:56000000
# done with chunk start:38000000, end:39000000
# start:56000000, end:57000000
# done with chunk start:36000000, end:37000000
# start:57000000, end:58000000
# done with chunk start:40000000, end:41000000
# start:58000000, end:59000000
# done with chunk start:11000000, end:12000000
# start:59000000, end:60000000
# done with chunk start:39000000, end:40000000
# start:60000000, end:61000000
# done with chunk start:34000000, end:35000000
# start:61000000, end:62000000
# done with chunk start:19000000, end:20000000
# start:62000000, end:63000000
# done with chunk start:42000000, end:43000000
# start:63000000, end:64000000
# done with chunk start:37000000, end:38000000
# start:64000000, end:65000000
# done with chunk start:24000000, end:25000000
# start:65000000, end:66000000
# done with chunk start:47000000, end:48000000
# start:66000000, end:67000000
# done with chunk start:48000000, end:49000000
# start:67000000, end:68000000
# done with chunk start:46000000, end:47000000
# start:68000000, end:69000000
# done with chunk start:50000000, end:51000000
# start:69000000, end:70000000
# done with chunk start:51000000, end:52000000
# start:70000000, end:71000000
# done with chunk start:43000000, end:44000000
# start:71000000, end:72000000
# done with chunk start:44000000, end:45000000
# start:72000000, end:73000000
# done with chunk start:54000000, end:55000000
# start:73000000, end:74000000
# done with chunk start:55000000, end:56000000
# start:74000000, end:75000000
# done with chunk start:56000000, end:57000000
# start:75000000, end:76000000
# done with chunk start:57000000, end:58000000
# start:76000000, end:77000000
# done with chunk start:49000000, end:50000000
# start:77000000, end:78000000
# done with chunk start:59000000, end:60000000
# start:78000000, end:79000000
# done with chunk start:60000000, end:61000000
# start:79000000, end:80000000
# done with chunk start:52000000, end:53000000
# start:80000000, end:81000000
# done with chunk start:13000000, end:14000000
# start:81000000, end:82000000
# done with chunk start:63000000, end:64000000
# start:82000000, end:83000000
# done with chunk start:64000000, end:65000000
# start:83000000, end:84000000
# done with chunk start:17000000, end:18000000
# start:84000000, end:85000000
# done with chunk start:66000000, end:67000000
# start:85000000, end:86000000
# done with chunk start:58000000, end:59000000
# start:86000000, end:87000000
# done with chunk start:25000000, end:26000000
# start:87000000, end:88000000
# done with chunk start:69000000, end:70000000
# start:88000000, end:89000000
# done with chunk start:61000000, end:62000000
# start:89000000, end:90000000
# done with chunk start:62000000, end:63000000
# start:90000000, end:91000000
# done with chunk start:72000000, end:73000000
# start:91000000, end:92000000
# done with chunk start:73000000, end:74000000
# start:92000000, end:93000000
# done with chunk start:65000000, end:66000000
# start:93000000, end:94000000
# done with chunk start:75000000, end:76000000
# start:94000000, end:95000000
# done with chunk start:67000000, end:68000000
# start:95000000, end:96000000
# done with chunk start:74000000, end:75000000
# start:96000000, end:97000000
# done with chunk start:78000000, end:79000000
# start:97000000, end:98000000
# done with chunk start:70000000, end:71000000
# start:98000000, end:99000000
# done with chunk start:80000000, end:81000000
# start:99000000, end:100000000
# done with chunk start:81000000, end:82000000
# start:100000000, end:101000000
# done with chunk start:82000000, end:83000000
# start:101000000, end:102000000
# done with chunk start:83000000, end:84000000
# start:102000000, end:103000000
# done with chunk start:84000000, end:85000000
# start:103000000, end:104000000
# done with chunk start:76000000, end:77000000
# start:104000000, end:105000000
# done with chunk start:86000000, end:87000000
# start:105000000, end:106000000
# done with chunk start:87000000, end:88000000
# start:106000000, end:107000000
# done with chunk start:88000000, end:89000000
# start:107000000, end:108000000
# done with chunk start:89000000, end:90000000
# start:108000000, end:109000000
# done with chunk start:90000000, end:91000000
# start:109000000, end:110000000
# done with chunk start:91000000, end:92000000
# start:110000000, end:111000000
# done with chunk start:92000000, end:93000000
# start:111000000, end:112000000
# done with chunk start:93000000, end:94000000
# start:112000000, end:113000000
# done with chunk start:94000000, end:95000000
# start:113000000, end:114000000
# done with chunk start:95000000, end:96000000
# start:114000000, end:115000000
# done with chunk start:96000000, end:97000000
# start:115000000, end:116000000
# done with chunk start:97000000, end:98000000
# start:116000000, end:117000000
# done with chunk start:98000000, end:99000000
# start:117000000, end:118000000
# done with chunk start:99000000, end:100000000
# start:118000000, end:119000000
# done with chunk start:100000000, end:101000000
# start:119000000, end:120000000
# done with chunk start:9000000, end:10000000
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# start:120000000, end:121000000
# done with chunk start:102000000, end:103000000
# start:121000000, end:122000000
# done with chunk start:103000000, end:104000000
# start:122000000, end:123000000
# done with chunk start:104000000, end:105000000
# start:123000000, end:124000000
# done with chunk start:105000000, end:106000000
# start:124000000, end:125000000
# done with chunk start:106000000, end:107000000
# start:125000000, end:126000000
# done with chunk start:107000000, end:108000000
# start:126000000, end:127000000
# done with chunk start:108000000, end:109000000
# start:127000000, end:128000000
# done with chunk start:109000000, end:110000000
# start:128000000, end:129000000
# done with chunk start:23000000, end:24000000
# start:129000000, end:130000000
# done with chunk start:111000000, end:112000000
# start:130000000, end:131000000
# done with chunk start:71000000, end:72000000
# start:131000000, end:132000000
# done with chunk start:113000000, end:114000000
# start:132000000, end:133000000
# done with chunk start:114000000, end:115000000
# start:133000000, end:133797422
# done with chunk start:112000000, end:113000000
# done with chunk start:116000000, end:117000000
# done with chunk start:117000000, end:118000000
# done with chunk start:77000000, end:78000000
# done with chunk start:110000000, end:111000000
# done with chunk start:120000000, end:121000000
# done with chunk start:121000000, end:122000000
# done with chunk start:122000000, end:123000000
# done with chunk start:123000000, end:124000000
# done with chunk start:124000000, end:125000000
# done with chunk start:125000000, end:126000000
# done with chunk start:126000000, end:127000000
# done with chunk start:127000000, end:128000000
# done with chunk start:128000000, end:129000000
# done with chunk start:129000000, end:130000000
# done with chunk start:130000000, end:131000000
# done with chunk start:131000000, end:132000000
# done with chunk start:132000000, end:133000000
# done with chunk start:85000000, end:86000000
# done with chunk start:118000000, end:119000000
# done with chunk start:119000000, end:120000000
# done with chunk start:133000000, end:133797422
# done with chunk start:45000000, end:46000000
# done with chunk start:115000000, end:116000000
# done with chunk start:53000000, end:54000000
# done with chunk start:101000000, end:102000000
# done with chunk start:68000000, end:69000000
# done with chunk start:79000000, end:80000000
# done with chunk start:20000000, end:21000000
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done with chunk start:41000000, end:42000000
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done writing
# wrote array to disk for dataset:hepg2_dnase_encode/ENCFF209DJG.chr10

# %%
## single-threaded version utilizes tiledb internal parallel writes, but not additional parallelization across chroms/tasks
# !db_ingest_single_threaded --tiledb_metadata tasks.dbingest.local.tsv \
    --tiledb_group hepg2_dnase_encode_single_threaded \
    --overwrite \
    --chrom_sizes hg38.chr10.size \
    --attribute_config encode_pipeline \
    --tile_size 9000

# %% [markdown]
# You can run the ingest code as a python function:

# %%
args={"tiledb_metadata":"tasks.dbingest.local.tsv",
      "tiledb_group":"hepg2_dnase_encode",
      "overwrite":True,
      "chrom_sizes":"hg38.chr10.size",
      "chrom_threads":1,
      "task_threads":1,
      "write_threads":1}

ingest(args)

# %% [markdown]
# ## Reading data from tiledb

# %%
chrom="chr10"
chromsize=133797422

# %%
#we can examine the array 
import tiledb 
data=tiledb.DenseArray("hepg2_dnase_encode/ENCFF209DJG.chr10",'r')

# %%
# %%time
subset=data[0:chromsize]
# Out:
# CPU times: user 35.4 s, sys: 28.3 s, total: 1min 3s
# Wall time: 5.17 s

# %%
print(subset.keys())
# Out:
# odict_keys(['pval_bigwig', 'fc_bigwig', 'count_bigwig_plus_5p', 'count_bigwig_minus_5p', 'idr_peak', 'overlap_peak', 'ambig_peak'])

# %%
import pyBigWig
import numpy as np 
data=pyBigWig.open("ENCFF842XRQ.bigWig")

# %%
# %%time
signal_data=np.nan_to_num(data.values(chrom,0,chromsize))
# Out:
# CPU times: user 10.8 s, sys: 4.25 s, total: 15 s
# Wall time: 14.9 s

# %% [markdown]
# ## Integration with batch producers

# %%
#unit tests for class seqdataloader.batchproducers.coordbased.coordstovals.BasicTiledbProfileCoordsToVals
from seqdataloader.batchproducers.coordbased.coordstovals.tiledb import *
# Out:
# Using TensorFlow backend.

# %%
#generate some test coords objects 
from collections import namedtuple
Coord=namedtuple('Coord','chrom start end isplusstrand')
coords=[Coord('chr1',1000000,2000000,True),
        Coord('chr2',1000000,2000000,True),
        Coord('chr3',1000000,2000000,True),
        Coord('chr4',1000000,2000000,True),
        Coord('chr5',1000000,2000000,True),
        Coord('chr6',1000000,2000000,True),
        Coord('chr7',1000000,2000000,True),
        Coord('chr1',1000000,2000000,False),
        Coord('chr2',1000000,2000000,False),
        Coord('chr3',1000000,2000000,False),
        Coord('chr4',1000000,2000000,False),
        Coord('chr5',1000000,2000000,False),
        Coord('chr6',1000000,2000000,False),
        Coord('chr7',1000000,2000000,False)]


pos_label_source_attribute="fc_bigwig"
neg_label_source_attribute="fc_bigwig"

# %%
#case 1: tiledb_paths is a string
tiledb_paths="/mnt/data/tiledb/ENCSR000EOY"
ctov=BasicTiledbProfileCoordsToVals(tiledb_paths=tiledb_paths,
                                    pos_label_source_attribute=pos_label_source_attribute,
                                    neg_label_source_attribute=neg_label_source_attribute)
string_vals=ctov.__call__(coords)
string_vals.shape
# Out:
# ---------------------------------------------------------------------------
# TileDBError                               Traceback (most recent call last)
# <ipython-input-32-6dd1196af45b> in <module>
#       4                                     pos_label_source_attribute=pos_label_source_attribute,
#       5                                     neg_label_source_attribute=neg_label_source_attribute)
# ----> 6 string_vals=ctov.__call__(coords)
#       7 string_vals.shape
#
# ~/seqdataloader/seqdataloader/batchproducers/coordbased/coordstovals/tiledb.py in __call__(self, coords)
#      62         assert len(coords)>0
#      63         self.ctx = tiledb.Ctx()
# ---> 64         return self.call_function(coords)
#      65
#      66     def query_tiledb(self,cur_tiledb_path,coords):
#
# ~/seqdataloader/seqdataloader/batchproducers/coordbased/coordstovals/tiledb.py in __call__string(self, coords)
#      52         self.tiledb_paths is a string
#      53         '''
# ---> 54         vals=self.query_tiledb(self.tiledb_paths,coords)
#      55         return vals
#      56
#
# ~/seqdataloader/seqdataloader/batchproducers/coordbased/coordstovals/tiledb.py in query_tiledb(self, cur_tiledb_path, coords)
#      72             coord=coords[i]
#      73             #open the tiledb for access in a pre-defined context
# ---> 74             with tiledb.DenseArray('.'.join([cur_tiledb_path,coord.chrom]), mode='r',ctx=self.ctx) as cur_array:
#      75                 if coord.isplusstrand:
#      76                     #query positive strand (or non-stranded entity)
#
# tiledb/libtiledb.pyx in tiledb.libtiledb.DenseArray.__init__()
#
# tiledb/libtiledb.pyx in tiledb.libtiledb.Array.__init__()
#
# tiledb/libtiledb.pyx in tiledb.libtiledb._raise_ctx_err()
#
# tiledb/libtiledb.pyx in tiledb.libtiledb._raise_tiledb_error()
#
# TileDBError: [TileDB::StorageManager] Error: Cannot open array; Array does not exist

# %%
coords=[Coord('chr1',1000,2000,True),
        Coord('chr2',1000,2000,True),
        Coord('chr3',1000,2000,True),
        Coord('chr4',1000,2000,True),
        Coord('chr5',1000,2000,True),
        Coord('chr6',1000,2000,True),
        Coord('chr7',1000,2000,True),
        Coord('chr1',1000,2000,False),
        Coord('chr2',1000,2000,False),
        Coord('chr3',1000,2000,False),
        Coord('chr4',1000,2000,False),
        Coord('chr5',1000,2000,False),
        Coord('chr6',1000,2000,False),
        Coord('chr7',1000,2000,False)]

# %%
string_vals=ctov.__call__(coords)

# %%
#case2: tiledb_paths is a list
tiledb_paths=["/mnt/data/tiledb/encode/dnase/ENCSR000EOY","/mnt/data/tiledb/encode/dnase/ENCSR000EOY","/mnt/data/tiledb/encode/dnase/ENCSR000EOY"]
ctov=BasicTiledbProfileCoordsToVals(tiledb_paths=tiledb_paths,
                                    pos_label_source_attribute=pos_label_source_attribute,
                                    neg_label_source_attribute=neg_label_source_attribute)
list_vals=ctov.__call__(coords)
list_vals

# %%
#case3: tiledb_paths is a dict
tiledb_paths={'mode0':"/mnt/data/tiledb/encode/dnase/ENCSR000EOY",
              'mode1':"/mnt/data/tiledb/encode/dnase/ENCSR000EOY",
              'mode2':"/mnt/data/tiledb/encode/dnase/ENCSR000EOY"}

ctov=BasicTiledbProfileCoordsToVals(tiledb_paths=tiledb_paths,
                                    pos_label_source_attribute=pos_label_source_attribute,
                                    neg_label_source_attribute=neg_label_source_attribute)
dict_vals=ctov.__call__(coords)
dict_vals
